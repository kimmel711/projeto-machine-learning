# %%
import pandas as pd

df = pd.read_csv('dataset.csv')

# %%
df.plot(kind="scatter", x= "m2", y= "valor");

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

modelo = linear_model.LinearRegression()

# %%
x = df[['m2']]
y = df[['valor']]

# %%
x_treino, x_teste, y_treino, y_teste= train_test_split(x, y)

# %%
y_treino
# Out:
#      valor
# 52  380036
# 11  169470
# 16  196578
# 24  252646
# 69  471289
# ..     ...
# 95  635888
# 75  535635
# 96  615959
# 18  231038
# 98  645710
#
# [75 rows x 1 columns]

# %%
modelo.fit(x_treino, y_treino)
# Out:
# LinearRegression()

# %%
previsoes = modelo.predict(x_teste)

# %%
acuracidade = round(r2_score(y_teste, previsoes) *100,2)
print(f"A acuracidade do modelo é de {acuracidade}%")
# Out:
# A acuracidade do modelo é de 98.12%

# %%
import pickle

with open("modelo_treinado.pkl", "wb") as file:
    pickle.dump(modelo,file)
